# %%
import sys
sys.path.append("..")
from Algoritmy import spectralclustering
import numpy as np
import pandas as pd
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# -*- coding: utf-8 -*-
import codecs
names = {}
f = codecs.open("Data/{0}_mapping.txt".format("Robotanik"))
for line in f.readlines():
    key, value = line.split(";")
    names[key] = value

# %%
data = pd.io.parsers.read_csv("Data/{0}_user_time_new.csv".format("Robotanik"), index_col=0)
data = data.ix[data.count(1)>10,(data.count()>5)]

corr = data.corr(method="spearman")
corr.unstack().hist()

# %%
def all_perms(elements):
    if len(elements) <=1:
        yield elements
    else:
        for perm in all_perms(elements[1:]):
            for i in range(len(elements)):
                yield perm[:i] + elements[0:1] + perm[i:]

def swapSol(sol1, sol2, clusterNumber):
    best_pr = 0.0
    for p in all_perms(range(clusterNumber)):
        hits = 0.0
        for i in range(clusterNumber):
            hits += sum((sol1==i) & (sol2==p[i]))
        pr = hits/sol1.size
        if pr > best_pr:
            best_pr = pr
            best = p
    
    sol3 = np.copy(sol2)
    for i in range(clusterNumber):
        sol3[sol2 == best[i]] = i
    return sol3

# %%
# -*- coding: utf-8 -*-
def clusterSpearmanSC(cor, sol, clusterNumber = 2, SCtype = 1, KMiter=20, kcut=0, plot = False, mutual=False):
    print "Clustering ..."
    SC = spectralclustering.Spectral_Clusterer(np.copy(cor))
    if kcut>0:
        if mutual:
            SC.kNearestMutual(kcut)
        else:
            SC.kNearest(kcut)
    
    solSC = SC.run(clusterNumber, SCtype, KMiter)
    solSC = swapSol(sol,solSC,clusterNumber)
    
    
    if plot:
        plt.figure()
        plt.plot(SC.eig_vect[solSC==0,1],SC.eig_vect[solSC==0,2],"ro")
        plt.plot(SC.eig_vect[solSC==1,1],SC.eig_vect[solSC==1,2],"go")
        plt.plot(SC.eig_vect[solSC==2,1],SC.eig_vect[solSC==2,2],"bo")
        plt.plot(SC.eig_vect[solSC==3,1],SC.eig_vect[solSC==3,2],"yo")
        for n in range(len(data.columns)):
            #plt.text(SC.eig_vect[n,1],SC.eig_vect[n,2], data.columns[n])
            if str(data.columns[n]) in names.keys():
                x = (names[str(data.columns[n])]).encode()
                plt.text(SC.eig_vect[n,1],SC.eig_vect[n,2], x)
    
    return np.sum(sol==solSC)*1.0/len(sol), solSC, SC

# %%
solution = np.array([0] * data.columns.size)

# %%
# -*- coding: utf-8 -*-
plt.rcParams['figure.figsize'] = 20, 20
pr,labels,SC = clusterSpearmanSC(corr, solution, clusterNumber = 4, KMiter = 50, kcut = corr.shape[0]/2, SCtype = 2, plot = True, mutual = False)
plt.savefig("Robotanik - names.png")
# Out:
# Clustering ...
# KMean
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-226-6091242d2f19> in <module>()
#       1
#       2 plt.rcParams['figure.figsize'] = 20, 20
# ----> 3 pr,labels,SC = clusterSpearmanSC(corr, solution, clusterNumber = 4, KMiter = 50, kcut = corr.shape[0]/2, SCtype = 2, plot = True, mutual = False)
#       4 plt.savefig("Robotanik - names.png")
#
# <ipython-input-224-b00d453bca61> in clusterSpearmanSC(cor, sol, clusterNumber, SCtype, KMiter, kcut, plot, mutual)
#      22             #plt.text(SC.eig_vect[n,1],SC.eig_vect[n,2], data.columns[n])
#      23             if str(data.columns[n]) in names.keys():
# ---> 24                 x = (names[str(data.columns[n])]).encode()
#      25                 plt.text(SC.eig_vect[n,1],SC.eig_vect[n,2], x)
#      26
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 2: ordinal not in range(128)

# %%
stats = pd.io.parsers.read_csv("Data/{0}_stats.csv".format("Robotanik"), index_col=0)
stats2 = {}
cos = ["median_casu","avg_casu","med_casu","avg_tahu","solved","attempts","min_solving_time","max_solving_time",
       "1PM_constant","3PM_constant","3PM_slope","3PM_randomness"]
for co in cos:
    print co
    stats2[co] = x = {}
    y = []
    for n in range(len(data.columns)):
        if int(data.columns[n]) in stats[co].keys():
            time = stats[co][int(data.columns[n])]
            if type(time)==str:
                time = time.split(":")
                time = int(time[0])*60 + int(time[1])
            x[data.columns[n]] = time
            y.append(time)
    stats2[co]["data"] = y
    stats2[co]["sorted"] = sorted(y)
    stats2[co]["max"] = max(y)
    stats2[co]["min"] = min(min(y),0)
# Out:
# median_casu
# avg_casu
# med_casu
# avg_tahu
# solved
# attempts
# min_solving_time
# max_solving_time
# 1PM_constant
# 3PM_constant
# 3PM_slope
# 3PM_randomness

# %%
def clusterSpearmanSC2(cor, sol, clusterNumber = 2, SCtype = 1, KMiter=20, kcut=0, plot = False, mutual=False, co = ""):
    print "Clustering ..."
    SC = spectralclustering.Spectral_Clusterer(np.copy(cor))
    if kcut>0:
        if mutual:
            SC.kNearestMutual(kcut)
        else:
            SC.kNearest(kcut)
    
    solSC = SC.run(clusterNumber, SCtype, KMiter)
    solSC = swapSol(sol,solSC,clusterNumber)
    
    
    if plot:
        plt.figure()
        for n in range(len(data.columns)):
            name = data.columns[n]
            if name in stats2[co].keys():
                #v = 1 - (1.*stats2[co][name]-stats2[co]["min"])/ (stats2[co]["max"]-stats2[co]["min"])
                v = stats2[co]["sorted"].index(stats2[co][name]) / float(len(stats2[co]["sorted"]))
                plt.plot(SC.eig_vect[n,1],SC.eig_vect[n,2], "o", color=(v,v,v, 1))
    
    return np.sum(sol==solSC)*1.0/len(sol), solSC, SC

# %%
for co in cos:
    plt.rcParams['figure.figsize'] = 20, 20
    pr,labels,SC = clusterSpearmanSC2(corr, solution, clusterNumber = 4, KMiter = 50, kcut = corr.shape[0]/2, SCtype = 2, plot = True, mutual = False, co =co)
    plt.savefig("Robotanik - {0} - order.png".format(co))
# Out:
# Clustering ...
# KMean
# 0.0 20
# 0.0657894736842 74
# 0.0526315789474 71
# 0.276315789474 163
# 0.0921052631579 78
# 0.263157894737 161
# 0.434210526316 204
# 0.25 156
# 0.315789473684 172
# 0.223684210526 147
# 0.486842105263 214
# 0.315789473684 172
# 0.526315789474 222
# 0.236842105263 153
# 0.460526315789 209
# 0.644736842105 296
# 0.618421052632 274
# 0.855263157895 598
# 0.289473684211 165
# 0.460526315789 209
# 0.144736842105 87
# 0.381578947368 195
# 0.736842105263
#  400
# 0.960526315789 1284
# 0.302631578947 169
# 0.565789473684 224
# 0.578947368421 229
# 0.723684210526 338
# 0.815789473684 518
# 0.684210526316 303
# 0.947368421053 1221
# 0.355263157895 188
# 0.407894736842 201
# 0.407894736842 201
# 0.776315789474 413
# 0.75 406
# 0.631578947368 288
# 0.197368421053 126
# 0.447368421053 208
# 0.697368421053 314
# 0.973684210526 1355
# 0.552631578947 223
# 0.710526315789 324
# 0.513157894737 219
# 0.802631578947 496
# 0.171052631579 109
# 0.763157894737 412
# 0.907894736842 861
# 0.921052631579 885
# 0.605263157895 244
# 0.118421052632 82
# 0.934210526316 979
# 0.368421052632 193
# 0.986842105263 1720
# 0.657894736842 297
# 0.789473684211 453
# 0.881578947368 727
# 0.394736842105 196
# 0.868421052632 673
# 0.0263157894737 32
# 0.0394736842105 62
# 0.342105263158 186
# 0.210526315789 143
# 0.671052631579 298
# 0.0 20
# 0.526315789474 222
# 0.105263157895 80
# 0.842105263158 555
# 0.486842105263 214
# 0.592105263158 235
# 0.894736842105 768
# 0.828947368421 520
# 0.0789473684211 77
# 0.157894736842 90
# 0.184210526316
#  115
# 0.131578947368 85
# Clustering ...
# KMean
# 0.0131578947368 39
# 0.118421052632 139
# 0.0657894736842 131
# 0.25 268
# 0.0526315789474 128
# 0.302631578947 310
# 0.486842105263 379
# 0.223684210526 262
# 0.289473684211 289
# 0.263157894737 276
# 0.539473684211 421
# 0.578947368421 447
# 0.684210526316 505
# 0.210526315789 236
# 0.5 397
# 0.618421052632 484
# 0.447368421053 364
# 0.842105263158 937
# 0.460526315789 365
# 0.644736842105 489
# 0.105263157895
#  133
# 0.381578947368 346
# 0.75 654
# 0.973684210526 1980
# 0.565789473684 437
# 0.407894736842 349
# 0.592105263158 451
# 0.605263157895 467
# 0.776315789474 731
# 0.657894736842 491
# 0.960526315789 1938
# 0.368421052632 339
# 0.394736842105 347
# 0.473684210526 370
# 0.802631578947 811
# 0.736842105263 605
# 0.723684210526 585
# 0.197368421053 220
# 0.697368421053 528
# 0.671052631579 499
# 0.934210526316 1751
# 0.526315789474 417
# 0.710526315789 547
# 0.421052631579 355
# 0.868421052632 985
# 0.171052631579 185
# 0.789473684211 761
# 0.894736842105 1113
# 0.986842105263 2633
# 0.552631578947 434
# 0.0921052631579 132
# 0.907894736842 1211
# 0.276315789474 283
# 0.947368421053 1830
# 0.631578947368 488
# 0.763157894737 661
# 0.881578947368 1108
# 0.302631578947 310
# 0.855263157895 958
# 0.0263157894737 46
# 0.0394736842105 120
# 0.328947368421 311
# 0.223684210526 262
# 0.513157894737 405
# 0.0 34
# 0.342105263158 327
# 0.144736842105 146
# 0.815789473684 866
# 0.434210526316 357
# 0.355263157895 331
# 0.828947368421 889
# 0.921052631579 1344
# 0.0657894736842 131
# 0.118421052632 139
# 0.184210526316 211
# 0.157894736842
#  160
# Clustering ...
# KMean
# 0.0 20
# 0.0657894736842 74
# 0.0526315789474 71
# 0.276315789474 163
# 0.0921052631579 78
# 0.263157894737 161
# 0.434210526316 204
# 0.25 156
# 0.315789473684 172
# 0.223684210526 147
# 0.486842105263 214
# 0.315789473684 172
# 0.526315789474 222
# 0.236842105263 153
# 0.460526315789 209
# 0.644736842105 296
# 0.618421052632 274
# 0.855263157895 598
# 0.289473684211 165
# 0.460526315789 209
# 0.144736842105 87
# 0.381578947368 195
# 0.736842105263 400
# 0.960526315789
#  1284
# 0.302631578947 169
# 0.565789473684 224
# 0.578947368421 229
# 0.723684210526 338
# 0.815789473684 518
# 0.684210526316 303
# 0.947368421053 1221
# 0.355263157895 188
# 0.407894736842 201
# 0.407894736842 201
# 0.776315789474 413
# 0.75 406
# 0.631578947368 288
# 0.197368421053 126
# 0.447368421053 208
# 0.697368421053 314
# 0.973684210526 1355
# 0.552631578947 223
# 0.710526315789 324
# 0.513157894737 219
# 0.802631578947 496
# 0.171052631579 109
# 0.763157894737 412
# 0.907894736842 861
# 0.921052631579 885
# 0.605263157895 244
# 0.118421052632 82
# 0.934210526316 979
# 0.368421052632 193
# 0.986842105263 1720
# 0.657894736842 297
# 0.789473684211 453
# 0.881578947368 727
# 0.394736842105 196
# 0.868421052632 673
# 0.0263157894737 32
# 0.0394736842105 62
# 0.342105263158 186
# 0.210526315789 143
# 0.671052631579 298
# 0.0 20
# 0.526315789474 222
# 0.105263157895 80
# 0.842105263158 555
# 0.486842105263 214
# 0.592105263158 235
# 0.894736842105 768
# 0.828947368421 520
# 0.0789473684211
#  77
# 0.157894736842 90
# 0.184210526316 115
# 0.131578947368 85
# Clustering ...
# KMean
# 0.0 3
# 0.0789473684211 6
# 0.144736842105 7
# 0.144736842105 7
# 0.0789473684211 6
# 0.460526315789 10
# 0.342105263158 9
# 0.236842105263 8
# 0.460526315789 10
# 0.236842105263 8
# 0.460526315789 10
# 0.657894736842 12
# 0.460526315789 10
# 0.236842105263 8
# 0.460526315789 10
# 0.657894736842 12
# 0.460526315789 10
# 0.907894736842 19
# 0.578947368421 11
# 0.578947368421 11
# 0.0394736842105
#  5
# 0.578947368421 11
# 0.802631578947 14
# 0.973684210526 30
# 0.236842105263 8
# 0.342105263158 9
# 0.460526315789 10
# 0.236842105263 8
# 0.947368421053 22
# 0.736842105263 13
# 0.960526315789 26
# 0.236842105263 8
# 0.342105263158 9
# 0.342105263158 9
# 0.736842105263 13
# 0.342105263158 9
# 0.657894736842 12
# 0.236842105263 8
# 0.657894736842 12
# 0.578947368421 11
# 0.907894736842 19
# 0.578947368421 11
# 0.460526315789 10
# 0.460526315789 10
# 0.855263157895 17
# 0.144736842105 7
# 0.578947368421 11
# 0.894736842105 18
# 0.986842105263 56
# 0.657894736842 12
# 0.0789473684211 6
# 0.855263157895 17
# 0.342105263158 9
# 0.855263157895 17
# 0.657894736842 12
# 0.802631578947 14
# 0.842105263158 16
# 0.0789473684211 6
# 0.802631578947 14
# 0.0 3
# 0.0789473684211 6
# 0.342105263158 9
# 0.342105263158 9
# 0.736842105263 13
# 0.0 3
# 0.144736842105 7
# 0.144736842105 7
# 0.736842105263 13
# 0.342105263158 9
# 0.144736842105 7
# 0.736842105263 13
# 0.934210526316 21
# 0.0394736842105 5
# 0.0394736842105 5
# 0.236842105263
#  8
# 0.144736842105 7
# Clustering ...
# KMean
# 0.986842105263 4859
# 0.921052631579 3561
# 0.947368421053 3974
# 0.671052631579 789
# 0.934210526316 3691
# 0.684210526316 823
# 0.578947368421 368
# 0.802631578947 1399
# 0.710526315789 996
# 0.75 1232
# 0.526315789474 292
# 0.434210526316 192
# 0.276315789474 108
# 0.855263157895 2026
# 0.592105263158 370
# 0.25 89
# 0.421052631579 188
# 0.210526315789 77
# 0.736842105263 1161
# 0.342105263158 145
# 0.894736842105 2802
# 0.631578947368 499
# 0.263157894737
#  107
# 0.105263157895 34
# 0.381578947368 151
# 0.473684210526 245
# 0.368421052632 149
# 0.328947368421 136
# 0.171052631579 63
# 0.394736842105 152
# 0.0526315789474 29
# 0.539473684211 334
# 0.5 276
# 0.618421052632 477
# 0.223684210526 88
# 0.197368421053 76
# 0.315789473684 129
# 0.763157894737 1238
# 0.513157894737 288
# 0.289473684211 125
# 0.0657894736842 30
# 0.644736842105 508
# 0.302631578947 127
# 0.486842105263 258
# 0.105263157895 34
# 0.868421052632 2419
# 0.157894736842 50
# 0.184210526316 64
# 0.0 14
# 0.460526315789 234
# 0.881578947368 2704
# 0.0263157894737 27
# 0.657894736842 715
# 0.0921052631579 33
# 0.447368421053 224
# 0.223684210526 88
# 0.0263157894737 27
# 0.552631578947 343
# 0.131578947368 37
# 0.960526315789 4313
# 0.907894736842 3518
# 0.697368421053 916
# 0.815789473684 1663
# 0.605263157895 404
# 0.973684210526 4323
# 0.565789473684 345
# 0.842105263158 1952
# 0.144736842105 47
# 0.355263157895 146
# 0.407894736842 165
# 0.0131578947368 21
# 0.0657894736842 30
# 0.828947368421 1865
# 0.776315789474
#  1349
# 0.723684210526 1080
# 0.789473684211 1350
# Clustering ...
# KMean
# 0.934210526316 6201
# 0.960526315789 6502
# 0.986842105263 8042
# 0.657894736842 1709
# 0.947368421053 6232
# 0.684210526316 2197
# 0.552631578947 1268
# 0.776315789474 2920
# 0.75 2738
# 0.736842105263 2727
# 0.526315789474 1160
# 0.486842105263 833
# 0.263157894737 485
# 0.881578947368 5123
# 0.578947368421 1304
# 0.105263157895 362
# 0.263157894737 485
# 0.157894736842 401
# 0.842105263158 4106
# 0.342105263158 538
# 0.855263157895 4695
# 0.565789473684
#  1299
# 0.289473684211 497
# 0.302631578947 506
# 0.236842105263 439
# 0.473684210526 803
# 0.328947368421 529
# 0.171052631579 423
# 0.197368421053 433
# 0.368421052632 578
# 0.592105263158 1362
# 0.513157894737 901
# 0.5 877
# 0.644736842105 1677
# 0.223684210526 436
# 0.0657894736842 288
# 0.407894736842 633
# 0.789473684211 3329
# 0.605263157895 1440
# 0.210526315789 434
# 0.0921052631579 344
# 0.671052631579 2184
# 0.355263157895 540
# 0.421052631579 647
# 0.0789473684211 335
# 0.868421052632 4818
# 0.144736842105 375
# 0.131578947368 373
# 0.315789473684 521
# 0.394736842105 606
# 0.921052631579 5377
# 0.184210526316 428
# 0.618421052632 1520
# 0.539473684211 1228
# 0.434210526316 680
# 0.105263157895 362
# 0.0263157894737 242
# 0.447368421053 703
# 0.0131578947368 236
# 0.907894736842 5216
# 0.973684210526 6749
# 0.723684210526 2619
# 0.828947368421 4068
# 0.631578947368 1643
# 0.894736842105 5186
# 0.460526315789 775
# 0.815789473684 3760
# 0.0 217
# 0.25 445
# 0.381578947368 586
# 0.0526315789474 264
# 0.0394736842105 244
# 0.802631578947 3442
# 0.710526315789 2449
# 0.697368421053 2333
# 0.763157894737
#  2774
# Clustering ...
# KMean
# 0.0 4
# 0.184210526316 12
# 0.0131578947368 6
# 0.526315789474 23
# 0.184210526316 12
# 0.631578947368 25
# 0.355263157895 16
# 0.236842105263 13
# 0.0657894736842 8
# 0.565789473684 24
# 0.236842105263 13
# 0.355263157895 16
# 0.5 22
# 0.184210526316 12
# 0.671052631579 28
# 0.236842105263 13
# 0.421052631579 18
# 0.842105263158 46
# 0.421052631579 18
# 0.565789473684 24
# 0.0921052631579 9
# 0.421052631579 18
# 0.394736842105
#  17
# 0.947368421053 151
# 0.526315789474 23
# 0.565789473684 24
# 0.776315789474 39
# 0.855263157895 48
# 0.684210526316 29
# 0.315789473684 15
# 0.881578947368 63
# 0.565789473684 24
# 0.5 22
# 0.421052631579 18
# 0.907894736842 71
# 0.684210526316 29
# 0.486842105263 21
# 0.157894736842 11
# 0.289473684211 14
# 0.526315789474 23
# 0.815789473684 41
# 0.315789473684 15
# 0.776315789474 39
# 0.644736842105 27
# 0.736842105263 32
# 0.0657894736842 8
# 0.355263157895 16
# 0.868421052632 55
# 0.0526315789474 7
# 0.315789473684 15
# 0.236842105263 13
# 0.973684210526 254
# 0.684210526316 29
# 0.184210526316 12
# 0.644736842105 27
# 0.894736842105 66
# 0.960526315789 220
# 0.736842105263 32
# 0.921052631579 104
# 0.0921052631579 9
# 0.0921052631579 9
# 0.473684210526 20
# 0.394736842105 17
# 0.565789473684 24
# 0.0131578947368 6
# 0.828947368421 42
# 0.0131578947368 6
# 0.934210526316 141
# 0.763157894737 38
# 0.802631578947 40
# 0.986842105263 311
# 0.684210526316 29
# 0.0921052631579 9
# 0.289473684211
#  14
# 0.0921052631579 9
# 0.157894736842 11
# Clustering ...
# KMean
# 0.118421052632 73
# 0.605263157895 171
# 0.684210526316 186
# 0.381578947368 116
# 0.328947368421 111
# 0.776315789474 216
# 0.276315789474 101
# 0.671052631579 177
# 0.486842105263 135
# 0.5 140
# 0.657894736842 174
# 0.5 140
# 0.736842105263 196
# 0.0394736842105 65
# 0.236842105263
#  98
# 0.0263157894737 63
# 0.855263157895 2228
# 0.263157894737 99
# 0.697368421053 187
# 0.473684210526 130
# 0.842105263158 2190
# 0.434210526316 127
# 0.644736842105 172
# 0.763157894737 215
# 0.171052631579 86
# 0.894736842105 2916
# 0.157894736842 80
# 0.0657894736842 68
# 0.0526315789474 66
# 0.881578947368 2835
# 0.539473684211 148
# 0.223684210526 91
# 0.0131578947368 62
# 0.723684210526 191
# 0.144736842105 78
# 0.960526315789 3070
# 0.592105263158 159
# 0.921052631579 3043
# 0.605263157895 171
# 0.171052631579 86
# 0.578947368421 158
# 0.421052631579 121
# 0.315789473684 108
# 0.105263157895 71
# 0.355263157895 113
# 0.407894736842 118
# 0.539473684211 148
# 0.210526315789 89
# 0.75 213
# 0.171052631579 86
# 0.118421052632 73
# 0.868421052632 2832
# 0.0789473684211 69
# 0.381578947368 116
# 0.447368421053 128
# 0.276315789474 101
# 0.0921052631579 70
# 0.342105263158 112
# 0.947368421053 3057
# 0.789473684211 1402
# 0.828947368421 2110
# 0.5 140
# 0.565789473684 157
# 0.0 61
# 0.802631578947 2005
# 0.368421052632 114
# 0.710526315789 189
# 0.236842105263
#  98
# 0.973684210526 3353
# 0.921052631579 3043
# 0.815789473684 2092
# 0.605263157895 171
# 0.302631578947 102
# 0.907894736842 3034
# 0.986842105263 3461
# 0.460526315789 129
# Clustering ...
# KMean
# 0.0 4.39
# 0.0921052631579 6.3
# 0.0394736842105 5.99
# 0.302631578947 7.72
# 0.0789473684211 6.29
# 0.315789473684 7.75
# 0.342105263158 7.95
# 0.236842105263 7.49
# 0.25 7.53
# 0.263157894737 7.61
# 0.394736842105 8.0
# 0.421052631579 8.05
# 0.671052631579 8.6
# 0.210526315789 7.26
# 0.460526315789 8.09
# 0.644736842105 8.56
# 0.513157894737 8.2
# 0.815789473684 9.38
# 0.263157894737 7.61
# 0.605263157895
#  8.35
# 0.118421052632 6.49
# 0.342105263158 7.95
# 0.736842105263 8.97
# 0.960526315789 10.68
# 0.421052631579 8.05
# 0.578947368421 8.24
# 0.618421052632 8.48
# 0.723684210526 8.88
# 0.789473684211 9.35
# 0.631578947368 8.53
# 0.986842105263 10.9
# 0.447368421053 8.06
# 0.486842105263 8.12
# 0.381578947368 7.98
# 0.763157894737 9.2
# 0.776315789474 9.26
# 0.697368421053 8.75
# 0.197368421053 7.15
# 0.407894736842 8.04
# 0.684210526316 8.71
# 0.934210526316 10.55
# 0.368421052632 7.96
# 0.710526315789 8.79
# 0.592105263158 8.3
# 0.828947368421 9.6
# 0.171052631579 6.85
# 0.75 9.06
# 0.868421052632 9.88
# 0.947368421053 10.64
# 0.552631578947 8.23
# 0.144736842105 6.5
# 0.907894736842 10.33
# 0.328947368421 7.93
# 0.973684210526 10.74
# 0.644736842105 8.56
# 0.802631578947 9.36
# 0.921052631579 10.35
# 0.473684210526 8.1
# 0.881578947368 10.11
# 0.0263157894737 4.97
# 0.0394736842105 5.99
# 0.289473684211 7.68
# 0.210526315789 7.26
# 0.5 8.13
# 0.0131578947368 4.4
# 0.539473684211 8.21
# 0.105263157895 6.31
# 0.842105263158 9.68
# 0.513157894737 8.2
# 0.552631578947 8.23
# 0.894736842105
#  10.22
# 0.855263157895 9.69
# 0.0657894736842 6.25
# 0.157894736842 6.52
# 0.184210526316 6.87
# 0.118421052632 6.49
# Clustering ...
# KMean
# 0.0 4.4
# 0.0921052631579 6.28
# 0.0394736842105 5.96
# 0.263157894737 7.67
# 0.0657894736842 6.26
# 0.315789473684 7.77
# 0.368421052632 7.9
# 0.236842105263 7.48
# 0.25 7.49
# 0.263157894737 7.67
# 0.434210526316 8.08
# 0.605263157895 8.43
# 0.684210526316 8.76
# 0.210526315789 7.27
# 0.539473684211 8.26
# 0.736842105263 9.02
# 0.421052631579 8.06
# 0.776315789474 9.51
# 0.289473684211 7.68
# 0.460526315789
#  8.11
# 0.131578947368 6.5
# 0.394736842105 7.99
# 0.763157894737 9.21
# 0.934210526316 10.86
# 0.328947368421 7.79
# 0.592105263158 8.39
# 0.618421052632 8.52
# 0.697368421053 8.93
# 0.815789473684 9.79
# 0.631578947368 8.58
# 0.973684210526 11.27
# 0.486842105263 8.15
# 0.578947368421 8.33
# 0.381578947368 7.93
# 0.671052631579 8.75
# 0.789473684211 9.6
# 0.75 9.14
# 0.197368421053 7.12
# 0.342105263158 7.83
# 0.644736842105 8.67
# 0.855263157895 10.05
# 0.447368421053 8.09
# 0.697368421053 8.93
# 0.565789473684 8.32
# 0.868421052632 10.08
# 0.171052631579 6.86
# 0.802631578947 9.65
# 0.921052631579 10.5
# 0.986842105263 12.77
# 0.513157894737 8.2
# 0.131578947368 6.5
# 0.907894736842 10.31
# 0.355263157895 7.88
# 0.947368421053 10.87
# 0.657894736842 8.69
# 0.723684210526 9.0
# 0.960526315789 10.98
# 0.394736842105 7.99
# 0.881578947368 10.13
# 0.0263157894737 5.02
# 0.0526315789474 5.97
# 0.302631578947 7.7
# 0.210526315789 7.27
# 0.473684210526 8.14
# 0.0131578947368 4.42
# 0.513157894737 8.2
# 0.105263157895 6.29
# 0.842105263158 9.95
# 0.539473684211 8.26
# 0.5 8.17
# 0.828947368421
#  9.91
# 0.894736842105 10.3
# 0.0657894736842 6.26
# 0.157894736842 6.52
# 0.184210526316 6.88
# 0.118421052632 6.49
# Clustering ...
# KMean
# 0.657894736842 -0.84
# 0.25 -1.15
# 0.25 -1.15
# 0.776315789474 -0.72
# 0.197368421053 -1.25
# 0.473684210526 -0.96
# 0.802631578947 -0.7
# 0.697368421053 -0.79
# 0.868421052632 -0.61
# 0.25 -1.15
# 0.394736842105 -1.07
# 0.0921052631579 -1.53
# 0.342105263158 -1.09
# 0.513157894737 -0.94
# 0.184210526316 -1.26
# 0.0789473684211 -1.56
# 0.881578947368 -0.54
# 0.434210526316 -1.04
# 0.157894736842 -1.32
# 0.947368421053
#  -0.3
# 0.578947368421 -0.88
# 0.473684210526 -0.96
# 0.223684210526 -1.24
# 0.342105263158 -1.09
# 0.921052631579 -0.45
# 0.289473684211 -1.14
# 0.565789473684 -0.89
# 0.513157894737 -0.94
# 0.105263157895 -1.49
# 0.552631578947 -0.91
# 0.131578947368 -1.39
# 0.407894736842 -1.05
# 0.171052631579 -1.27
# 0.763157894737 -0.73
# 0.973684210526 0.0
# 0.144736842105 -1.35
# 0.105263157895 -1.49
# 0.881578947368 -0.54
# 0.934210526316 -0.42
# 0.736842105263 -0.75
# 0.986842105263 0.19
# 0.236842105263 -1.22
# 0.342105263158 -1.09
# 0.578947368421 -0.88
# 0.0657894736842 -1.6
# 0.315789473684 -1.12
# 0.0394736842105 -1.65
# 0.0131578947368 -1.89
# 0.0 -3.37
# 0.710526315789 -0.78
# 0.631578947368 -0.86
# 0.736842105263 -0.75
# 0.815789473684 -0.69
# 0.434210526316 -1.04
# 0.315789473684 -1.12
# 0.960526315789 -0.21
# 0.0394736842105 -1.65
# 0.842105263158 -0.67
# 0.631578947368 -0.86
# 0.828947368421 -0.68
# 0.407894736842 -1.05
# 0.5 -0.95
# 0.342105263158 -1.09
# 0.618421052632 -0.87
# 0.710526315789 -0.78
# 0.671052631579 -0.82
# 0.302631578947 -1.13
# 0.197368421053 -1.25
# 0.539473684211
#  -0.93
# 0.855263157895 -0.65
# 0.907894736842 -0.46
# 0.0263157894737 -1.72
# 0.684210526316 -0.81
# 0.578947368421 -0.88
# 0.776315789474 -0.72
# 0.460526315789 -1.0
# Clustering ...
# KMean
# 0.223684210526 1.07
# 0.236842105263 1.08
# 0.618421052632 1.38
# 0.315789473684 1.14
# 0.0526315789474 0.93
# 0.368421052632 1.17
# 0.776315789474 1.5
# 0.315789473684 1.14
# 0.723684210526 1.45
# 0.197368421053 1.06
# 0.868421052632 1.55
# 0.868421052632 1.55
# 0.592105263158 1.33
# 0.381578947368 1.18
# 0.552631578947 1.26
# 0.802631578947 1.51
# 0.815789473684 1.52
# 0.75 1.49
# 0.671052631579
#  1.4
# 0.736842105263 1.48
# 0.157894736842 1.01
# 0.460526315789 1.21
# 0.710526315789 1.44
# 0.776315789474 1.5
# 0.973684210526 1.82
# 0.421052631579 1.19
# 0.578947368421 1.29
# 0.0789473684211 0.95
# 0.75 1.49
# 0.828947368421 1.53
# 0.526315789474 1.24
# 0.276315789474 1.12
# 0.25 1.09
# 0.697368421053 1.42
# 0.921052631579 1.68
# 0.513157894737 1.23
# 0.671052631579 1.4
# 0.605263157895 1.35
# 0.986842105263 2.08
# 0.631578947368 1.39
# 0.855263157895 1.54
# 0.828947368421 1.53
# 0.486842105263 1.22
# 0.25 1.09
# 0.565789473684 1.28
# 0.184210526316 1.05
# 0.960526315789 1.8
# 0.447368421053 1.2
# 0.934210526316 1.76
# 0.868421052632 1.55
# 0.0921052631579 0.96
# 0.144736842105 1.0
# 0.118421052632 0.99
# 0.907894736842 1.6
# 0.539473684211 1.25
# 0.381578947368 1.18
# 0.0526315789474 0.93
# 0.355263157895 1.15
# 0.118421052632 0.99
# 0.0 0.75
# 0.486842105263 1.22
# 0.315789473684 1.14
# 0.421052631579 1.19
# 0.631578947368 1.39
# 0.0131578947368 0.83
# 0.0394736842105 0.89
# 0.381578947368 1.18
# 0.197368421053 1.06
# 0.276315789474 1.12
# 0.105263157895
#  0.98
# 0.0131578947368 0.83
# 0.947368421053 1.79
# 0.302631578947 1.13
# 0.157894736842 1.01
# 0.631578947368 1.39
# 0.460526315789 1.21
